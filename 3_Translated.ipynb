# %%
# !pip install translate

# %%
import pandas as pd

# %%
df = pd.read_csv("data/hasil_preprocessingData.csv")
df
# Out:
#                                               full_text
# 0     kasih pilih capres mau hapus usia syarat kerja...
# 1     kasi capres mau hapus diskriminasi usia loker2...
# 2     mk mode asli hapus ambang batas 4 laku tahun 2...
# 3     mk hapus ambang batas parlemen 4 mahfud ungkit...
# 4     alhamdulillah mohon bapak capres kalo jadi pre...
# ...                                                 ...
# 1101  soekarno polyglot tetap guling kan meski dukun...
# 1102  tambahin hoax kalau anak nya cukup umur minim ...
# 1103  licin khas politis seniorpanjang umur pak jk b...
# 1104  kok jadi orang bisa2nya peka males njelasin sa...
# 1105  jokowi sen kanan belok kiri jadi nnti skrang p...
#
# [1106 rows x 1 columns]

# %%
# # Mengambil data mulai dari baris 2665
# start_row = 881
# df = df.iloc[start_row-1:]  # -1 karena indeks dimulai dari 0

# %%
df = df.head(150)

# %%
df
# Out:
#                                               full_text
# 880   sudah legowo fokus aja nyiapin anak2 kamu buat...
# 881   1 demo putus mk siapsiap wapres kamu gibran 2 ...
# 882   anak haram konstitusi umur 35 th jadi wapres a...
# 883   yaa lah kakek umur 72 tahun tinggal nyari voni...
# 884   pertama kali jadi wapres umur bawah 40tahun ka...
# ...                                                 ...
# 1025   maksain anak bawah umur jadi wapres curang bukan
# 1026  hey gibran kau msih blum cukup umur buat lanju...
# 1027  minimal umur 40 tahun matang jadi wapres gibra...
# 1028  jd wapres aja ipk segitu enggak masalah umur b...
# 1029  tau aku sih om gugat tuh lebih prosedural milu...
#
# [150 rows x 1 columns]

# %%
from translate import Translator

def convert_eng(tweet):
    translator = Translator(to_lang="en", from_lang="id")
    translation = translator.translate(tweet)
    return translation

df['tweet_english'] = df['full_text'].apply(convert_eng)

# %%
df
# Out:
#                                               full_text  \
# 880   sudah legowo fokus aja nyiapin anak2 kamu buat...
# 881   1 demo putus mk siapsiap wapres kamu gibran 2 ...
# 882   anak haram konstitusi umur 35 th jadi wapres a...
# 883   yaa lah kakek umur 72 tahun tinggal nyari voni...
# 884   pertama kali jadi wapres umur bawah 40tahun ka...
# ...                                                 ...
# 1025   maksain anak bawah umur jadi wapres curang bukan
# 1026  hey gibran kau msih blum cukup umur buat lanju...
# 1027  minimal umur 40 tahun matang jadi wapres gibra...
# 1028  jd wapres aja ipk segitu enggak masalah umur b...
# 1029  tau aku sih om gugat tuh lebih prosedural milu...
#
#                                           tweet_english
# 880   already legowo focus just like nyiapin your ch...
# 881   1 demo break up mk ready to prepare your vice ...
# 882   the bastard child of the constitution at the a...
# 883   yes, 72-year-old grandpa is just living with a...
# ...

# %%
df = df.head(125)

# %%
# df.to_csv("")
